# %%
import pandas

# %%
data = pandas.ExcelFile('300002164403.xlsx')

# %%
data2 = pandas.read_excel(data, skiprows=5)

# %%
data2
# Out:
#                   Unnamed: 0  \
# 0                       Země
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                      EU 28
# 6                Eurozóna 19
# 7                     v tom:
# 8                     Belgie
# 9                  Bulharsko
# 10           Česká republika
# 11                    Dánsko
# 12                  Estonsko
# 13                    Finsko
# 14                   Francie
# 15                Chorvatsko
# 16                     Irsko
# 17                    Itálie
# 18                      Kypr
# 19                     Litva
# 20                  Lotyšsko
# 21             Lucembursko1)
# 22                  Maďarsko
# 23                     Malta
# 24                   Německo
# 25                Nizozemsko
# 26                    Polsko
# 27               Portugalsko
# 28                  Rakousko
# 29                  Rumunsko
# 30                     Řecko
# ...

# %%
data2.iloc[0]
# Out:
# Unnamed: 0                                                 Země
# Unnamed: 1     Studují či se jinak připravují na výkon povolání
# Unnamed: 2                                                  NaN
# Unnamed: 3                                                  NaN
# Unnamed: 4                                                  NaN
# Unnamed: 5           Péče o děti či zdravotně postižené dospělé
# Unnamed: 6                                                  NaN
# Unnamed: 7                                                  NaN
# Unnamed: 8                                                  NaN
# Unnamed: 9                                     Zdravotní důvody
# Unnamed: 10                                                 NaN
# Unnamed: 11                                                 NaN
# Unnamed: 12                                                 NaN
# Unnamed: 13                                            Důchodci
# Unnamed: 14                                                 NaN
# ...

# %%
data3= pandas.read_excel(data, skiprows=5, header = 1, index_col=0)

# %%
# Out:
#                          Studují či se jinak připravují na výkon povolání  \
# Země
# NaN                                              In education or training
# NaN                                                   15 - 24 let / years
# NaN                                                                  ženy
# NaN                                                                 Women
# EU 28                                                                 NaN
# Eurozóna 19                                                           NaN
# v tom:                                                                NaN
# Belgie                                                                NaN
# Bulharsko                                                             NaN
# Česká republika                                                       NaN
# Dánsko                                                                NaN
# Estonsko                                                              NaN
# ...
